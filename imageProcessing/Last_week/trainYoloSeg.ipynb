# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8n-seg.pt')

path = '/Users/sukird/Python_learning/imageProcessing/Last_week/train.yaml'

train_model = model.train(data= path, epochs = 50, batch= -1)
# Out:
# Ultralytics YOLOv8.0.200 🚀 Python-3.11.3 torch-2.1.0 CPU (Apple M1)
# ...
