# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import Image

img = cv2.imread('./week2-2023/imageEx/F310b.jpg',0)
plt.imshow(img,cmap='gray')

# %%
equ = cv2.equalizeHist(img)
plt.imshow(equ,cmap='gray')
